# %%
from pathlib import Path

from src.utils.config import get_config_from_path
from inference_v2 import VideoProcessor

# %%
config = get_config_from_path('./configs/detection_yolov8n-seg.py')

# %% [markdown]
# ### Пути и параметры

# %%
OUT_DIR = Path('./results')  # Общая папка с результатами. При прогоне в ней будут создаваться подпапки с названием файлов

# %%
processor = VideoProcessor(config, result_dir=OUT_DIR, make_video=True, save_all_pics=True)

# %%
in_file = Path('./13-10.cine') # путь до видео, возможны форматы cine (пока только он)

# %% [markdown]
# ### Запуск обработки

# %%
res = processor.process(in_file)

# %% [markdown]
# ### Можно посмотреть результат по кадрам

# %%
frame_idx = 50

res['result'][frame_idx]['full_mask']
